# %% [markdown]
# #### Tensorflow and Keras

# %%
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout

# %%
(X_train, y_train), (X_test, y_test) = load_data()
X_train, X_test = X_train / 255., X_test / 255.

# %%
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dropout(.3),
    Dense(64, activation='relu'),
    Dropout(.2),
    Dense(10, activation='softmax'),
])
model.compile(optimizer="adam", loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3160 - accuracy: 0.9057
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1809 - accuracy: 0.9457
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1452 - accuracy: 0.9566
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1244 - accuracy: 0.9627
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1134 - accuracy: 0.9647
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1037 - accuracy: 0.9684
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0975 - accuracy: 0.9701
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0924 - accuracy: 0.9715
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0868 - accuracy: 0.9737
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0826 - accuracy: 0.9743

# %%
loss, acc = model.evaluate(X_test, y_test)
print("Accuracy", acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0759 - accuracy: 0.9781
# Accuracy 0.9781000018119812

# %% [markdown]
# #### PyTorch

# %%
import torch

x, y = torch.tensor([1, 2, 3]), torch.tensor([[1, 2, 3], [4, 5, 6]])
x, y
# Out:
# (tensor([1, 2, 3]),
#  tensor([[1, 2, 3],
#          [4, 5, 6]]))

# %%
x.shape, y.shape
# Out:
# (torch.Size([3]), torch.Size([2, 3]))

# %%
len(x.shape), len(y.shape)
# Out:
# (1, 2)

# %% [markdown]
# #### Theano

# %%
import numpy as np
import theano
import theano.Tensor as T

x, y = T.dscalar('x'), T.dscalar('y')
z = x + y

add = theano.function([x, y], z)
add(1, 2)
